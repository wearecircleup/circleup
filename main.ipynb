# %%
from dataclasses import dataclass

@dataclass
class User:
    first_name: str
    last_name: str
    phone_number: str

    def __post_init__(self):
        if not self.__validate_phone_number():
            raise ValueError("El número de teléfono debe tener 10 dígitos y ser numérico.")

    def __validate_phone_number(self):
        return len(self.phone_number) == 10 and self.phone_number.isdigit()


# Intentar crear una instancia con un número de teléfono inválido
try:
    user_invalid = User(first_name="Jane", last_name="Doe", phone_number="abc1234567")
    print("Usuario creado exitosamente!")
except ValueError as e:
    print("Error al crear usuario:", e)
# Out:
# Error al crear usuario: El número de teléfono debe tener 10 dígitos y ser numérico.

# %%
country_codes = {
    "United States": "+1",
    "United Kingdom": "+44",
    "Australia": "+61",
    "Canada": "+1",
    "India": "+91"
}

def check_country(countrycode,digits):
    def decorator(func):
        def wrapper(**kwargs):
            country = [country for country,code in country_codes.items() if code == kwargs.get('codes')][0]
            if countrycode != country:
                raise ValueError('El Pais no corresponde a al indicativo ingresado')
            elif len(kwargs.get('phone').replace('-','').replace(' ','')) != digits:
                raise ValueError(f'El Numero de digitos no es el correcto para {country}')
            return func(**kwargs)
        return wrapper
    return decorator

@check_country('India',10)
def get_phonenumber(phone,codes):
    country = [country for country,code in country_codes.items() if code == codes]
    return f'[{country[0]}] [{codes}] {phone}'

try:
    print(get_phonenumber(phone='319 447-7860',codes='+1'))
except ValueError as e:
    print(f'Error de valor: {e}')
# Out:
# Error de valor: El Pais no corresponde a al indicativo ingresado

# %%
# Simulación de la base de datos de usuarios y permisos
user_permissions = {
    "user1": ["read", "write"],
    "user2": ["read"],
    "user3": []
}

# Definición de un decorador para verificar los permisos del usuario
def check_permissions(permission_required):
    def decorator(func):
        def wrapper(username, *args, **kwargs):
            if permission_required in user_permissions.get(username, []):
                return func(username, *args, **kwargs)
            else:
                raise PermissionError(f"El usuario '{username}' no tiene permiso para realizar esta acción.")
        return wrapper
    return decorator

# Función que requiere permisos de escritura
@check_permissions("write")
def write_data_to_database(username, data):
    print(f"Guardando datos en la base de datos como '{username}': {data}")

# Función que requiere permisos de lectura
@check_permissions("read")
def read_data_from_database(username):
    print(f"Leyendo datos de la base de datos como '{username}'")

# Simulación de usuarios intentando acceder a las funciones
try:
    write_data_to_database("user1", "Datos sensibles")
    read_data_from_database("user2")
    read_data_from_database("user3")  # Esto debería lanzar una excepción
except PermissionError as e:
    print("Error de permisos:", e)
# Out:
# Guardando datos en la base de datos como 'user1': Datos sensibles
# Leyendo datos de la base de datos como 'user2'
# Error de permisos: El usuario 'user3' no tiene permiso para realizar esta acción.

# %%
users_type = {'Keys':{'Sentinel':'Admin','Nomads':'Volunteer','Crew':'Learner'}}
new = {}

# %%
from dataclasses import dataclass, field, fields, asdict, astuple

@dataclass
class TableClass:
    columns: int = field(repr=False)
    rows: int
    table_name: str
    table_schema: str = field(repr=False)
    table_db: str

    def as_dict(self):
        return asdict(self)
    
    def as_json(self):
        return {field.name: getattr(self,field.name) for field in fields(self)}

instance = TableClass(10,12,'Name','Schema','DataBase')
instance.as_dict()
# Out:
# {'columns': 10,
#  'rows': 12,
#  'table_name': 'Name',
#  'table_schema': 'Schema',
#  'table_db': 'DataBase'}

# %%
from dataclasses import dataclass, field

@dataclass
class Usuario:
    nombre: str
    apellido: str
    email: str
    firestore: str = None
    def update_profile(self, **kwargs):
        for key, value in kwargs.items():
            if hasattr(self, key):
                setattr(self, key, value)

    def set_firestore(self, key):
        self.firestore = key

    
    def update_profile(self,**kwagrs):
        for key,value in kwagrs.items():
            if hasattr(self,key):
                setattr(self,key,value)

    def catch_update(self,**kwagrs):
        catch_changes = {}
        for key,value in kwagrs.items():
            if hasattr(self,key):
                catch_changes[key] = [value,getattr(self,key)]
        for _ ,value in catch_changes.items():
            if value[0] == value[1]:
                value.append(False)
            else: value.append(True)
        return catch_changes
    

alumn = {'nombre':"Juan", 'apellido':"Perez", 'email':"juan@example.com"}
changes = {'apellido':"Pelaez", 'email':"juan@mail.com"}
# Crear un alumno
alumno = Usuario(**alumn)
alumno.update_profile(**changes)

# %%
import json
textkey = "{\n  \"type\": \"service_account\",\n  \"project_id\": \"circleup-dd60f\",\n  \"private_key_id\": \"80b7db2920ea985be703d63bd1c7c7d86af6cdb6\",\n  \"private_key\": \"-----BEGIN PRIVATE KEY-----\\nMIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQCB7RZQrc+vUjBC\\npSzCwzTQwqzu/r1mcEqmv9zELkyuTm4LOU/knv9pBpvyRB/RlZ08T78xJ+p/uiAU\\nNP8+0tECnTceh5GkCdNOITKWZ+N3Jc99ixk0Rh1hiQ/WgRJAlVVTDgrnl0qjHWH3\\nWUqVzCGXwUrMto0ZfrH/vZp8gkBFX29BdHDopuYvOFEIFXFIFSs75OfUXPpoJKuK\\nU8mcRHnj8htOqNt+Tcvf8OSZwzFV2/gko8o1OhYrDKkcV/w6e7w2uq/GP39vBuqG\\nXZ/J+gTxGfdvy6+xqwm1/14FZ0p++0i9cLUQaZM1tAvAAHupHgOAXOES1A8h5zWu\\nXPqCy8//AgMBAAECggEAE8GnAoajjY/MWd3/A/Cl/9aScFcZGtIZb+i927EEpP61\\nGgzRery4rtI79WdphTegbLLdqk5dCKYXSatTYsywzpp0braDrXN3B6rho+BRROVh\\ne0AjCYFd515to5sF2P88NcBtZRDq3wnRQ0j3H/cl5osUYjOiGg3baD1/F87Akiu8\\n6osFxV5av3dYQPITVhZzxvVYgaph80f/0bglphIFPR6qBUF4r/pD6bulBv3RWGti\\nb72qn03kMv3LIOpaui38tUUaMdFzkdlOPWsQ5C6vbcCimM/I2Ab1nIDnv8XKZQZs\\necHyTQfCDnZwh6ioTLew5nIKH2aVY7oWSeFLgLOFEQKBgQC3QWnP4Rn9xP/svXeV\\n4KVmu3FaasBO6LZbA4BrPmY/O8bRikMp5DRuT20PTG4EBQ8glrwK1A6IXz0Gz0aE\\nbjSOAiF/I7+Ivt/gZ8tfLsOQAXHsEqSXbjkUwtmD0hPILnFLc12GjtjU6rzuP+cQ\\naw0/yrUAONst8vjNd2LUlWugUQKBgQC1gEsmma1MWSkgh79CA1imux78gLIxqk54\\njoh6EPb/dDDOvxR0dt5MG/BCGk5mP5U3jKtolBWqxqKPah9coaEh0SMMhMLzGMkU\\nwvh8MpFxax1D9RDBKH1vo75vsN2RecLWnEfQ75aZHZ/+EV0YvyNivo71Z2VHNegF\\n570JtVknTwKBgFGrRlPNlv7Ah+niumPCHRR+ntLT1maUUYiYM+gXhAvUQRPrUWle\\n+XrbzNfPkQwbkRVN9/m/bcaa4yCgyWWFk8hh7Lmznc18e1uQBlOiDKel7TZvTIjs\\nJ2Y4PCYCPqys/fLJNDoeeUXSY2audfScMOhoF2hE7nE44mb3OMVS3gcxAoGANdle\\ncpFdrS022oPr5rX/c1hJFTlJpRqWNYZ0T2MBJUFfybc/Zl5uDb6sRbBwWj27E8QU\\nhu6IjyZnzIz7yQvbNqFJ+Mja3i0YW6SM/Kw0IqZZBHSNCAHvVVQLiC+9TRAHEo1D\\ncWXkFIGJmmOkb1cmNIG9AGowzjPcJwRePackUFkCgYBVSo316gHD3kPy8MpvAQKA\\n9OhuwNJOrrV2L7ADYhNAqxKXJlHqBgkK4NLNYiuwdYBvlJO3uMdnOZMdgMqqMoXu\\nXUS5KUCCkiouM+R1WxrGXA36qd7k1p407bKmUmABncmjopk44sDeF1RYaNHTsZO2\\nUQdIG9k2Bp9qFxsAdVYS+A==\\n-----END PRIVATE KEY-----\\n\",\n  \"client_email\": \"firebase-adminsdk-1niv0@circleup-dd60f.iam.gserviceaccount.com\",\n  \"client_id\": \"113930465813144394828\",\n  \"auth_uri\": \"https://accounts.google.com/o/oauth2/auth\",\n  \"token_uri\": \"https://oauth2.googleapis.com/token\",\n  \"auth_provider_x509_cert_url\": \"https://www.googleapis.com/oauth2/v1/certs\",\n  \"client_x509_cert_url\": \"https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-1niv0%40circleup-dd60f.iam.gserviceaccount.com\",\n  \"universe_domain\": \"googleapis.com\"\n}\n"
key = json.loads(textkey)

# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore
path = './gallery/pensum.xlsx'

def load_sheets(sheet_name):
  feature = ['General Pensum','Respuesta'] 
  sheet = pd.read_excel(path,sheet_name=sheet_name)[feature]
  last_valid_row = sheet.last_valid_index() + 1
  sheet_dictionary = sheet.iloc[:last_valid_row].set_index('General Pensum').to_dict()['Respuesta']
  if all(sheet_dictionary.values()):
    return '\n'.join([f'{key.replace('\n','').lower()}: {value}' for key, value in sheet_dictionary.items()])
  else:
    raise ValueError('missing-info')
  
def load_pensum():
  sheets = ['Información General','Estructura del Curso','Metodología','Evaluación','Recursos Adicionales','Experiencia']
  return '\n'.join([load_sheets(sheet_name) for sheet_name in sheets])

print(load_pensum())
# Out:
# nombre curso: Introducción a la Programación Creativa con Scratch
# área temática: Tecnología, Tecnología, Tecnología
# modalidad: Presencial
# número de sesiones: 4
# duración/sesión: 2
# público objetivo: 18-21 años, 18-21 años
# objetivo general: Desarrollar el pensamiento computacional y la creatividad de los participantes a través de la creación de proyectos interactivos con Scratch.
# objetivos específicos: Comprender los conceptos básicos de la programación (secuencias, bucles, condicionales).
#
# Utilizar Scratch para crear animaciones, juegos y historias interactivas.
#
# Desarrollar habilidades de resolución de problemas y pensamiento lógico.
#
# Fomentar la creatividad y la expresión personal a través de la programación.
# tema #1: Introducción a Scratch
# contenido #1: Interfaz de Scratch
# Bloques básicos
# Movimiento y apariencia de objetos
# Bloques básicos
# Movimiento y apariencia de objetos
# actividades #1: Crear un personaje y hacerlo moverse
# Cambiar el fondo y agregar sonidos
# materiales #1: Computadores con Scratch instalado
# Proyector
# tema #2: Secuencias y bucles
# contenido #2: Orden de instrucciones
# Repetición de acciones con bucles
# actividades #2: Crear una animación simple
# Hacer que un personaje siga un camino
# materiales #2: Computadores con Scratch instalado
# Proyector
# tema #3: Condicionales y eventos
# contenido #3: Tomar decisiones con condicionales
# Reaccionar a eventos (clics, teclas)
# actividades #3: Crear un juego interactivo sencillo
# Agregar controles al juego
# materiales #3: Computadores con Scratch instalado
# Proyector
# tema #4: Proyecto final
# contenido #4: Repaso de conceptos aprendidos
# Desarrollo de un proyecto creativo
# actividades #4: Crear una historia interactiva, un juego más complejo o una animación con múltiples personajes
# materiales #4: Computadores con Scratch instalado
# Proyector
# enfoque pedagógico: Aprendizaje activo y colaborativo.
# estrategias de enseñanza: Explicaciones breves y concisas.
#
# Demostraciones prácticas.
#
# Ejercicios guiados y autónomos.
#
# Trabajo en parejas y grupos pequeños.
#
# Presentación y discusión de proyectos.
# recursos didácticos: Tutoriales interactivos de Scratch.
#
# Ejemplos de proyectos.
#
# Tarjetas con instrucciones y desafíos.
#
# Música y efectos de sonido.
# criterios de evaluación: Participación activa en las actividades.
# Comprensión de los conceptos básicos de programación.
# Creatividad y originalidad en los proyectos.
# Capacidad para trabajar en equipo.
#
# Instrumentos de evaluación:
# Observación directa del desempeño en clase.
# Revisión de los proyectos creados.
# Rúbrica de evaluación de proyectos.
#
# Ponderación:
# Participación: 20%
# Proyectos: 60%
# Trabajo en equipo: 20%
# bibliografía básica: “Scratch para niños” de Majed Marji
#
# “Aprende a programar con Scratch” de la Fundación Scratch
# bibliografía complementaria: Sitio web oficial de Scratch: https://scratch.mit.edu/
#
# Comunidad de Scratch en línea: https://scratch.mit.edu/discuss/
# notas adicionales: No se requieren conocimientos previos de programación.
#
# Se recomienda traer audífonos para trabajar de manera individual en los proyectos.
#
# Se fomentará un ambiente de respeto, colaboración y diversión durante el curso.
# experiencia académica: Mi formación académica incluye una Licenciatura en Educación con especialización en Tecnología Educativa y un Máster en Informática Educativa. Durante mis estudios, me apasioné por el potencial de la programación como herramienta para fomentar la creatividad y el pensamiento crítico en los jóvenes.
# experiencia profesional: Soy desarrollador de software educativo y he trabajado en el diseño e implementación de cursos de programación para niños y jóvenes. He colaborado con diversas organizaciones educativas para promover el uso de Scratch como herramienta de aprendizaje, y he impartido talleres y charlas sobre programación creativa en escuelas y centros comunitarios.

# %%
import pandas as pd

path = './gallery/pensum.xlsx'

def load_sheet(sheet_name):
    feature = ['General Pensum', 'Respuesta']
    sheet = pd.read_excel(path, sheet_name=sheet_name)[feature]
    last_valid_row = sheet['General Pensum'].last_valid_index() + 1
    return sheet.iloc[:last_valid_row]

def check_missing_data(sheet, sheet_name):
    missing_data = sheet[sheet.isnull().any(axis=1)]
    if not missing_data.empty:
        return '\n'.join(
            f"{sheet_name}: {row['General Pensum']}"
            for idx, row in missing_data.iterrows()
        )
    return None

def sheet_to_dict(sheet):
    """Convierte un DataFrame en un diccionario utilizando las columnas 'General Pensum' y 'Respuesta'."""
    return '\n'.join(
        f"{key.replace('\n', '').lower()}: {value}" 
        for key, value in sheet.set_index('General Pensum')['Respuesta'].to_dict().items()
    )

def load_sheets(sheet_name):
    """Carga una hoja de Excel, verifica datos faltantes y la convierte a un string formateado."""
    sheet = load_sheet(sheet_name)
    missing_info = check_missing_data(sheet, sheet_name)
    if missing_info:
        raise ValueError(f'Info Incompleta:\n{missing_info}')
    return sheet_to_dict(sheet)

def load_pensum():
    """Carga y procesa todas las hojas especificadas."""
    sheets = ['Información General', 'Estructura del Curso', 'Metodología', 'Evaluación', 'Recursos Adicionales', 'Experiencia']
    return '\n'.join(load_sheets(sheet_name) for sheet_name in sheets)

try:
    print(load_pensum())
except ValueError as e:
    print(e)
# Out:
# nombre curso: Introducción a la Programación Creativa con Scratch
# área temática: Tecnología, Tecnología, Tecnología
# modalidad: Presencial
# número de sesiones: 4
# duración/sesión: 2
# público objetivo: 18-21 años, 18-21 años
# objetivo general: Desarrollar el pensamiento computacional y la creatividad de los participantes a través de la creación de proyectos interactivos con Scratch.
# objetivos específicos: Comprender los conceptos básicos de la programación (secuencias, bucles, condicionales).
#
# Utilizar Scratch para crear animaciones, juegos y historias interactivas.
#
# Desarrollar habilidades de resolución de problemas y pensamiento lógico.
#
# Fomentar la creatividad y la expresión personal a través de la programación.
# tema #1: Introducción a Scratch
# contenido #1: Interfaz de Scratch
# Bloques básicos
# Movimiento y apariencia de objetos
# Bloques básicos
# Movimiento y apariencia de objetos
# actividades #1: Crear un personaje y hacerlo moverse
# Cambiar el fondo y agregar sonidos
# materiales #1: Computadores con Scratch instalado
# Proyector
# tema #2: Secuencias y bucles
# contenido #2: Orden de instrucciones
# Repetición de acciones con bucles
# actividades #2: Crear una animación simple
# Hacer que un personaje siga un camino
# materiales #2: Computadores con Scratch instalado
# Proyector
# tema #3: Condicionales y eventos
# contenido #3: Tomar decisiones con condicionales
# Reaccionar a eventos (clics, teclas)
# actividades #3: Crear un juego interactivo sencillo
# Agregar controles al juego
# materiales #3: Computadores con Scratch instalado
# Proyector
# tema #4: Proyecto final
# contenido #4: Repaso de conceptos aprendidos
# Desarrollo de un proyecto creativo
# actividades #4: Crear una historia interactiva, un juego más complejo o una animación con múltiples personajes
# materiales #4: Computadores con Scratch instalado
# Proyector
# enfoque pedagógico: Aprendizaje activo y colaborativo.
# estrategias de enseñanza: Explicaciones breves y concisas.
#
# Demostraciones prácticas.
#
# Ejercicios guiados y autónomos.
#
# Trabajo en parejas y grupos pequeños.
#
# Presentación y discusión de proyectos.
# recursos didácticos: Tutoriales interactivos de Scratch.
#
# Ejemplos de proyectos.
#
# Tarjetas con instrucciones y desafíos.
#
# Música y efectos de sonido.
# criterios de evaluación: Participación activa en las actividades.
# Comprensión de los conceptos básicos de programación.
# Creatividad y originalidad en los proyectos.
# Capacidad para trabajar en equipo.
#
# Instrumentos de evaluación:
# Observación directa del desempeño en clase.
# Revisión de los proyectos creados.
# Rúbrica de evaluación de proyectos.
#
# Ponderación:
# Participación: 20%
# Proyectos: 60%
# Trabajo en equipo: 20%
# bibliografía básica: “Scratch para niños” de Majed Marji
#
# “Aprende a programar con Scratch” de la Fundación Scratch
# bibliografía complementaria: Sitio web oficial de Scratch: https://scratch.mit.edu/
#
# Comunidad de Scratch en línea: https://scratch.mit.edu/discuss/
# notas adicionales: No se requieren conocimientos previos de programación.
#
# Se recomienda traer audífonos para trabajar de manera individual en los proyectos.
#
# Se fomentará un ambiente de respeto, colaboración y diversión durante el curso.
# experiencia académica: Mi formación académica incluye una Licenciatura en Educación con especialización en Tecnología Educativa y un Máster en Informática Educativa. Durante mis estudios, me apasioné por el potencial de la programación como herramienta para fomentar la creatividad y el pensamiento crítico en los jóvenes.
# experiencia profesional: Soy desarrollador de software educativo y he trabajado en el diseño e implementación de cursos de programación para niños y jóvenes. He colaborado con diversas organizaciones educativas para promover el uso de Scratch como herramienta de aprendizaje, y he impartido talleres y charlas sobre programación creativa en escuelas y centros comunitarios.

# %%
a = []

# %%
a.__len__()
# Out:
# 0

# %%
import streamlit as st
from vega_datasets import data

source = data.barley()

# %%
source
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]
